# %%
import pandas as pd

# %%
p = catalog.load('parameters')

features=p["features"]
targets=p["targets"]
additional_values = p["additional_values"]
names=p["names"]
# Out:
# [02/25/24 01:35:48] INFO     Loading data from 'parameters' (MemoryDataSet)...                  ]8;id=800458;file:///home/jack/miniconda3/envs/sampler/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=900928;file:///home/jack/miniconda3/envs/sampler/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\

# %%
scaler=catalog.load('scaler')
treatment=catalog.load('treatment')
# Out:
#                     INFO     Loading data from 'scaler' (PickleDataSet)...                      ]8;id=772548;file:///home/jack/miniconda3/envs/sampler/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=347702;file:///home/jack/miniconda3/envs/sampler/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                     INFO     Loading data from 'treatment' (PickleDataSet)...                   ]8;id=336822;file:///home/jack/miniconda3/envs/sampler/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=541599;file:///home/jack/miniconda3/envs/sampler/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\

# %%
path = '/home/jack/sampler/data/01_raw/all_data_p3_new.csv'
data = pd.read_csv(path)[features + targets + additional_values]
data.describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           r_ext_pAl    r_ext_pMeO  pAl_richness          Pg_f       Tg_Tmax  \
# count  2.297300e+04  2.297300e+04  22973.000000  2.215800e+04  22158.000000
# mean   1.049824e-06  1.071501e-06      1.169136  3.126090e+07   3735.772195
# std    2.005413e-06  2.052421e-06      0.434820  3.770002e+07   1289.792259
# min    6.768163e-08  2.500000e-08      0.500000  2.805839e+05   1064.961059
# 25%    1.801608e-07  1.400811e-07      0.772822  1.860936e+06   2757.483956
# 50%    2.327620e-07  2.269487e-07      1.129344  1.406711e+07   3426.215408
# 75%    7.490519e-07  8.144027e-07      1.562599  4.888404e+07   4576.742028
# max    9.997724e-06  9.999294e-06      2.000000  1.425095e+08   7515.099043
#
#            sim_time
# count  22158.000000
# mean       9.156835
# std       12.763085
# min        0.079048
# 25%        0.404611
# ...

# %%
from sampler.pipelines.analysis.postprocessing_functions import prepare_benchmark

renaming_cols = {v1: v2 for v1, v2 in zip(features + targets, names['features'] + names['targets'])}

df = prepare_benchmark(df=data, f=features, t=targets, treatment=treatment).rename(columns=renaming_cols)
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        Al radius [micron]  CuO radius [micron]  Al richness  \
# 0                1.128748             7.087133     0.515552
# 1                3.485223             9.346632     1.890437
# 2                5.337451             8.423015     1.458583
# 3                9.805790             6.135023     1.816405
# 4                9.934559             0.780171     0.552286
# ...                   ...                  ...          ...
# 22968            0.250000             0.116040     2.000000
# 22969            0.250000             0.140585     2.000000
# 22970            0.250000             0.170323     2.000000
# 22971            0.250000             0.206351     2.000000
# 22972            0.250000             0.250000     2.000000
#
#        Final Pressure [MPa]  Combustion Temperature [K]   sim_time  \
# ...

# %%
data['quality'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# out_of_bounds_feat    14660
# not_interesting        5720
# time_out                938
# interest                839
# sim_error               815
# out_of_bounds_tar         1
# Name: quality, dtype: int64

# %%
data['quality'].describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# count                  22973
# unique                     6
# top       out_of_bounds_feat
# freq                   14660
# Name: quality, dtype: object

# %%
df['quality'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# out_of_bounds_feat    14660
# not_interesting        5720
# time_out                938
# interest                839
# sim_error               815
# out_of_bounds_tar         1
# Name: quality, dtype: int64

# %%
df.groupby('quality').count()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     Al radius [micron]  CuO radius [micron]  Al richness  \
# quality
# interest                           839                  839          839
# not_interesting                   5720                 5720         5720
# out_of_bounds_feat               14660                14660        14660
# out_of_bounds_tar                    1                    1            1
# sim_error                          815                  815          815
# time_out                           938                  938          938
#
#                     Final Pressure [MPa]  Combustion Temperature [K]  sim_time
# quality
# interest                             839                         839       839
# not_interesting                     5720                        5720      5720
# ...

# %%
interest_df = df[df['quality'] == 'interest']

# %%
interest_df.describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        Al radius [micron]  CuO radius [micron]  Al richness  \
# count          839.000000           839.000000   839.000000
# mean             0.227746             0.545060     1.547910
# std              0.023480             1.067143     0.192710
# min              0.200025             0.200196     1.177379
# 25%              0.210637             0.213224     1.409445
# 50%              0.226060             0.226855     1.533762
# 75%              0.227599             0.514755     1.695039
# max              0.329934             9.990992     2.000000
#
#        Final Pressure [MPa]  Combustion Temperature [K]    sim_time
# count            839.000000                  839.000000  839.000000
# mean               1.438445                 3351.376146   14.538613
# std                0.296251                  204.196879    5.106127
# ...

# %% [markdown]
# ### Simulation time

# %%
# Use plotly to plot "Final Pressure [MPa]" vs "sim_time"
import plotly.express as px

fig = px.scatter(interest_df, x="Final Pressure [MPa]", y="sim_time",  color="quality")
fig.show()

# %% [markdown]
# ### Note that the interest region is [2000, 4500] but points start at 3000, as simulation time is very large for those values

# %%
# Get interest region from parameters
interest_region = p['interest_region']
interest_region
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'Pg_f': [1000000.0, 2000000.0], 'Tg_Tmax': [2000, 4500]}

# %%
fig = px.scatter(interest_df, x="Combustion Temperature [K]", y="sim_time",  color="sim_time")
fig.show()

# %%
fig = px.scatter(interest_df, x="Final Pressure [MPa]", y="sim_time",  color="sim_time")
fig.show()

# %%
fig = px.scatter(interest_df, x="Al radius [micron]", y="sim_time",  color="sim_time")
fig.show()

# %%
fig = px.scatter(interest_df, x="CuO radius [micron]", y="sim_time",  color="sim_time")
fig.show()

# %%
fig = px.scatter(interest_df, x="Al richness", y="sim_time",  color="sim_time")
fig.show()

# %% [markdown]
# ### Histogram of times (using unknown hardware)

# %%
fig = px.histogram(interest_df, x="sim_time", title="Histogram of simulation times")
fig.show()

# %%
fig = px.scatter(interest_df, x="Final Pressure [MPa]", y="Combustion Temperature [K]",  color="sim_time")
fig.show()
